# %%
import pandas as pd
import altair as alt

df_di = pd.read_excel('Resources/portafolio_innova.xlsx')

def SetAreaOCDE(sector):
    if sector == 'Agrícola (excepto vitivinicola)':
        return 'Ciencias Agrícolas'
    elif sector == 'Alimentos (excepto vitivinicola)':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Servicios de ingeniería o de conocimiento':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Manufactura de metales básicos':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Química, caucho y plásticos (excepto industria farmaceutica)':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Minería y metalurgia extractiva':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Construcción':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Farmaceutica':
        return 'Ciencias médicas, Ciencias de la salud'
    elif sector == 'Comercio y retail':
        return 'Ciencias Sociales'
    elif sector == 'Pesca y acuicultura':
        return 'Ciencias Agrícolas'
    elif sector == 'Servicios empresariales administrativos y de apoyo':
        return 'Ciencias Sociales'
    elif sector == 'Forestal':
        return 'Ciencias Agrícolas'
    elif sector == 'Gestión de desechos':   #NO SÉ COMO CLASIFICARLO MEJOR
        return 'Gestión de desechos'
    elif sector == 'Educación':
        return 'Ciencias Sociales'
    elif sector == 'Ganadero':
        return 'Ciencias Agrícolas'
    elif sector == 'Manufactura de maquinaria y equipos (Metalmecánico)':
        return 'Ingeniería, Tecnología ...'
    elif sector ==  'Tecnologías de la información':
        return 'Ingeniería, Tecnología ...'       #PODRIA QUEDAR COMO CIENCIAS NATURALES
                                              # según: https://vrid.udec.cl/sites/default/files/Areas%20de%20Investigación%20OCDE_0.pdf#overlay-context=formularioseinstructivos
    elif sector == 'Salud y asistencia social':
        return 'Ciencias médicas, Ciencias de la salud'        
    elif sector == 'Logística y Transporte':
        return 'Ingeniería, Tecnología ...' 
    elif sector == 'Recursos Hídricos':
        return 'Ciencias Naturales'
    elif sector == 'Manufactura de no metálicos':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Energético':
        return 'Ciencias Naturales'
    elif sector == 'Sector público':
        return 'Ciencias Sociales'
    elif sector =='Banca y sector financiero': 
        return 'Ciencias Sociales'
    elif sector == 'Telecomunicaciones':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Inmobiliario':
        return 'Ingeniería, Tecnología ...'
    elif sector == 'Industria creativa y de esparcimiento':
        return 'Ciencias Sociales'
    elif sector == 'Asociaciones y organizaciones no empresariales ni gubernamentales':
        return 'Ciencias Sociales'
    elif sector == 'Turismo':
        return 'Ciencias Sociales'
    elif sector == 'Otras industrias manufactureras':
        return 'Ingeniería, Tecnología ...'
    return sector

def SetAreaANID(sector):
    if sector == 'Agrícola (excepto vitivinicola)':
        return 'Tecnología, Agrícola y Productividad'
    elif sector == 'Alimentos (excepto vitivinicola)':
        return 'Tecnología y ciencias Silvoagropecuarias'
    elif sector == 'Servicios de ingeniería o de conocimiento':
        return 'Tecnología y ciencias de la Ingeniería'
    elif sector == 'Manufactura de metales básicos':
        return 'Tecnología y ciencias de la Ingeniería'
    elif sector == 'Química, caucho y plásticos (excepto industria farmaceutica)':
        return 'Ciencias exactas y naturales'
    elif sector == 'Minería y metalurgia extractiva':
        return 'Ciencias exactas y naturales'
    elif sector == 'Construcción':
        return 'Tecnología y ciencias de la Ingeniería'
    elif sector == 'Farmaceutica':
        return 'Ciencias exactas y naturales'
    elif sector == 'Comercio y retail':
        return 'Ciencias jurídicas, económicas y administrativas'
    elif sector == 'Pesca y acuicultura':
        return 'Tecnología y ciencias Silvoagropecuarias'
    elif sector == 'Servicios empresariales administrativos y de apoyo':
        return 'Ciencias jurídicas, económicas y administrativas'
    elif sector == 'Forestal':
        return 'Tecnología y ciencias Silvoagropecuarias'
    elif sector == 'Gestión de desechos':  
        return 'Ciencias sociales'
    elif sector == 'Educación':
        return 'Ciencias sociales'
    elif sector == 'Ganadero':
        return 'Tecnología y ciencias Silvoagropecuarias'
    elif sector == 'Manufactura de maquinaria y equipos (Metalmecánico)':
        return 'Tecnología y ciencias de la Ingeniería'
    elif sector ==  'Tecnologías de la información':
        return  'Tecnología y ciencias de la Ingeniería'
    elif sector == 'Salud y asistencia social':
        return  'Tecnología y ciencias médicas'
    elif sector == 'Logística y Transporte':
        return 'Tecnología y ciencias de la Ingeniería'
    elif sector == 'Recursos Hídricos':
        return 'Ciencias exactas y naturales'
    elif sector == 'Manufactura de no metálicos':
        return 'Tecnología y ciencias de la Ingeniería'
    elif sector == 'Energético':
        return 'Ciencias jurídicas, económicas y administrativas'
    elif sector == 'Sector público':
        return 'Ciencias jurídicas, económicas y administrativas'
    elif sector =='Banca y sector financiero': 
        return 'Ciencias jurídicas, económicas y administrativas'
    elif sector == 'Telecomunicaciones':
        return 'Tecnología y ciencias de la Ingeniería'
    elif sector == 'Inmobiliario':
        return 'Tecnología y ciencias de la Ingeniería'
    elif sector == 'Industria creativa y de esparcimiento':
        return 'Ciencias sociales'
    elif sector == 'Asociaciones y organizaciones no empresariales ni gubernamentales':
        return 'Ciencias sociales'
    elif sector == 'Turismo':
        return 'Ciencias sociales'
    elif sector == 'Otras industrias manufactureras':
        return 'Tecnología y ciencias de la Ingeniería'
    return sector

# %%
df_di.head()
# Out:
#        codigo             foco_apoyo tipo_intervencion  \
# 0  09AAP-6740              Renuévate          Subsidio
# 1  09AAP-6741              Renuévate          Subsidio
# 2  09AAP-7335              Renuévate          Subsidio
# 3  09ACS-7457  Desarrolla innovación          Subsidio
# 4  09ANT-7090    Consolida y Expande          Subsidio
#
#                                         instrumento  \
# 0  Apoyo A La Atracción De Profesionales Y Técnicos
# 1  Apoyo A La Atracción De Profesionales Y Técnicos
# 2  Apoyo A La Atracción De Profesionales Y Técnicos
# 3                 Apoyo Elaboración Capital Semilla
# 4                       Apoyo Negocios Tecnológicos
#
#         instrumento_homologado estado_data rut_beneficiario  \
# 0               Capital Humano  FINALIZADO        772954409
# 1               Capital Humano  FINALIZADO        768322201
# 2               Capital Humano  FINALIZADO        965328009
# 3              Capital Semilla  FINALIZADO        966913304
# 4  Apoyo Negocios Tecnológicos  FINALIZADO        969726807
#
#                             beneficiario  \
# 0  INGENIERIA Y DESARROLLO FORESTAL S.A.
# 1                      ORION FORESTAL SA
# 2                     SOUTHERN GROUP S A
# 3                            DICTUC S.A.
# 4                               VPT S.A.
#
#                                               titulo  \
# 0  biomasa forestal del manejo sustentable del bo...
# 1  desarrollo de sistemas de recolección de bioma...
# 2  mejoramiento y optimizacion de la linea de pro...
# 3  apoyo a la elaboración de estudios de preinver...
# 4  implementación comercial del sistema automátic...
#
#                                             objetivo  ...  \
# 0  diseñar un modelo de producción de biomasa for...  ...
# 1  desarrollar conocimiento por medio de la inves...  ...
# 2  el objetivo de este proyecto es potenciar la p...  ...
# 3  fortalecer la definición y formulación, además...  ...
# 4  se busca generar, por medio de la herramienta ...  ...
#
#    modelo_de_circularidad  codigo_region  \
# 0     Suministro circular            8.0
# 1     Suministro circular            8.0
# 2                     NaN            6.0
# 3                     NaN           13.0
# 4                     NaN           13.0
#
#                                     regionejecucion  tramo_ventas  inicio_act  \
# 0                                 Región del Biobío       Mediana  1999-06-06
# 1                                 Región del Biobío       Pequeña  2007-05-11
# 2  Región del Libertador General Bernardo O'Higgins  Microempresa  1993-01-01
# 3                  Región Metropolitana de Santiago        Grande  1994-03-02
# 4                  Región Metropolitana de Santiago       Pequeña  2001-12-21
#
#                                   sector_equivalente       mo_1        mo_2  \
# 0                    Agrícola (excepto vitivinicola)   Forestal  Energético
# 1  Servicios empresariales administrativos y de a...   Forestal  Energético
# 2                                  Comercio y retail        NaN         NaN
# 3          Servicios de ingeniería o de conocimiento  Industria         NaN
# 4                      Tecnologías de la información        NaN         NaN
#
#   mo_3 tendencia_final
# 0  NaN   Sin tendencia
# 1  NaN   Sin tendencia
# 2  NaN   Sin tendencia
# 3  NaN   Sin tendencia
# 4  NaN   Sin tendencia
#
# [5 rows x 33 columns]

# %%
df_di['foco_apoyo'].unique()
# Out:
# array(['Renuévate', 'Desarrolla innovación', 'Consolida y Expande',
#        'Entorno para la innovación', 'Desarrolla innovación con I+D'],
#       dtype=object)

# %%
#Nos centraremos en el foco de desarrollo innovación con I+D
df_id = df_di[df_di['foco_apoyo']=='Desarrolla innovación con I+D'].copy()
df_id['area_ocde'] = df_id['sector_equivalente'].apply(SetAreaOCDE)
df_id['area_anid'] = df_id['sector_equivalente'].apply(SetAreaANID)

df_id.head(3)
# Out:
#           codigo                     foco_apoyo tipo_intervencion  \
# 57    09DCO-7200  Desarrolla innovación con I+D          Subsidio
# 138  09PDAC-6892  Desarrolla innovación con I+D          Subsidio
# 139  09PDAC-6902  Desarrolla innovación con I+D          Subsidio
#
#                                           instrumento  \
# 57                 Consorcios Tecnológicos Desarrollo
# 138  Perfiles De Programas Otras Especies Potenciales
# 139  Perfiles De Programas Otras Especies Potenciales
#
#                                instrumento_homologado estado_data  \
# 57                            Consorcios Tecnológicos  FINALIZADO
# 138  Perfiles De Programas Otras Especies Potenciales  FINALIZADO
# 139  Perfiles De Programas Otras Especies Potenciales  FINALIZADO
#
#     rut_beneficiario                                       beneficiario  \
# 57         609100001                               UNIVERSIDAD DE CHILE
# 138        760080519  ROLANDO STANGE MOLINA INVERSIONES\n           ...
# 139        815184009                     UNIVERSIDAD CATOLICA DEL NORTE
#
#                                                 titulo  \
# 57   constitución y desarrollo proyecto consorcio f...
# 138  perfil para cultivo de cobia, rachycentron can...
# 139  bases técnico-económicas para el cultivo suste...
#
#                                               objetivo  ...  \
# 57   el propósito principal del proyecto es consoli...  ...
# 138  el objetivo general de este proyecto/perfil es...  ...
# 139  formulación del perfil de programa acuícola de...  ...
#
#                       regionejecucion  tramo_ventas  inicio_act  \
# 57   Región Metropolitana de Santiago        Grande  1993-01-01
# 138               Región de los Lagos  Microempresa  2008-02-14
# 139                Región de Coquimbo        Grande  1993-01-01
#
#       sector_equivalente  mo_1 mo_2 mo_3 tendencia_final           area_ocde  \
# 57             Educación   NaN  NaN  NaN   Sin tendencia   Ciencias Sociales
# 138  Pesca y acuicultura   NaN  NaN  NaN   Sin tendencia  Ciencias Agrícolas
# 139            Educación   NaN  NaN  NaN   Sin tendencia   Ciencias Sociales
#
#                                     area_anid
# 57                          Ciencias sociales
# 138  Tecnología y ciencias Silvoagropecuarias
# 139                         Ciencias sociales
#
# [3 rows x 35 columns]

# %% [markdown]
# # 5. ¿En qué áreas se está invirtiendo más en la región los últimos 3 años?

# %%
# seteamos los últimos 3 años
df_id = df_id[df_id['anio_adjudicacion'].isin([2019,2020,2021])].copy()
# Comenzamos a trabajar con Biobio y RM ---- Se pueden seguir agregando regiones para explorar visualizaciones
df_id = df_id[df_id['regionejecucion'].isin(['Región del Biobío','Región Metropolitana de Santiago'])]

# Agrupamos por 
df_pg5 = df_id.copy()
df_pg5 = df_pg5.groupby(['sector_equivalente','regionejecucion','anio_adjudicacion'])\
               .agg({'aprobado_corfo':'sum','aprobado_privado':'sum','monto_consolidado_ley':'sum'})\
               .reset_index()
df_pg5['monto_consolidado_ley'] = df_pg5['monto_consolidado_ley']/1000000000  #miles de millones
df_pg5.head()
# Out:
#                  sector_equivalente                   regionejecucion  \
# 0   Agrícola (excepto vitivinicola)  Región Metropolitana de Santiago
# 1   Agrícola (excepto vitivinicola)  Región Metropolitana de Santiago
# 2   Agrícola (excepto vitivinicola)  Región Metropolitana de Santiago
# 3  Alimentos (excepto vitivinicola)  Región Metropolitana de Santiago
# 4  Alimentos (excepto vitivinicola)  Región Metropolitana de Santiago
#
#    anio_adjudicacion  aprobado_corfo  aprobado_privado  monto_consolidado_ley
# 0               2019     250679600.0        89938400.0               0.140647
# 1               2020             0.0               0.0               1.304790
# 2               2021             0.0               0.0               0.065892
# 3               2019     219207950.0       225438418.0               2.792677
# 4               2020             0.0               0.0               4.677976

# %%
# Gráfico lo consideramos con información de data innovación -- sector Equivalente
chart_pg5A = alt.Chart(df_pg5).mark_bar().encode(
                y = alt.Y('sector_equivalente:O',title=None),
                x = alt.X('monto_consolidado_ley:Q', title='Miles de millones'),
                column = alt.Column('regionejecucion',title=None) 
            )
chart_pg5A
# Out:
# alt.Chart(...)

# %%
# PARA AREA OCDE
df_pg5B = df_id.copy()
df_pg5B = df_pg5B.groupby(['area_ocde','regionejecucion','anio_adjudicacion'])\
               .agg({'aprobado_corfo':'sum','aprobado_privado':'sum','monto_consolidado_ley':'sum'})\
               .reset_index()
df_pg5B['monto_consolidado_ley'] = df_pg5B['monto_consolidado_ley']/1000000000  #miles de millones
df_pg5B.head()
# Out:
#             area_ocde                   regionejecucion  anio_adjudicacion  \
# 0  Ciencias Agrícolas  Región Metropolitana de Santiago               2019
# 1  Ciencias Agrícolas  Región Metropolitana de Santiago               2020
# 2  Ciencias Agrícolas  Región Metropolitana de Santiago               2021
# 3  Ciencias Agrícolas                 Región del Biobío               2019
# 4  Ciencias Agrícolas                 Región del Biobío               2020
#
#    aprobado_corfo  aprobado_privado  monto_consolidado_ley
# 0     250679600.0        89938400.0              19.222657
# 1             0.0               0.0               5.502355
# 2             0.0               0.0               0.065892
# 3      76217472.0       114435128.0               0.000000
# 4             0.0               0.0               4.305586

# %%
# Gráfico lo consideramos con información de data innovación -- AREA OCDE
chart_pg5B = alt.Chart(df_pg5B).mark_bar().encode(
                y = alt.Y('area_ocde:O',title=None),
                x = alt.X('monto_consolidado_ley:Q', title='Miles de millones'),
                column = alt.Column('regionejecucion',title=None) 
            )
chart_pg5B
# Out:
# alt.Chart(...)

# %%
# PARA AREA ANID
df_pg5C = df_id.copy()
df_pg5C = df_pg5C.groupby(['area_anid','regionejecucion','anio_adjudicacion'])\
               .agg({'aprobado_corfo':'sum','aprobado_privado':'sum','monto_consolidado_ley':'sum'})\
               .reset_index()
df_pg5C['monto_consolidado_ley'] = df_pg5C['monto_consolidado_ley']/1000000000  #miles de millones
df_pg5C.head()
# Out:
#                       area_anid                   regionejecucion  \
# 0  Ciencias exactas y naturales  Región Metropolitana de Santiago
# 1  Ciencias exactas y naturales  Región Metropolitana de Santiago
# 2  Ciencias exactas y naturales  Región Metropolitana de Santiago
# 3  Ciencias exactas y naturales                 Región del Biobío
# 4  Ciencias exactas y naturales                 Región del Biobío
#
#    anio_adjudicacion  aprobado_corfo  aprobado_privado  monto_consolidado_ley
# 0               2019     135922480.0       201598320.0               2.876519
# 1               2020     109386000.0        32308880.0              14.197326
# 2               2021     219519242.0       100787917.0               0.332038
# 3               2019     498165750.0       289433175.0               0.207141
# 4               2020     150000000.0       278571864.0               1.103830

# %%
# Gráfico lo consideramos con información de data innovación -- AREA ANID
chart_pg5C = alt.Chart(df_pg5C).mark_bar().encode(
                y = alt.Y('area_anid:O',title=None),
                x = alt.X('monto_consolidado_ley:Q', title='Miles de millones'),
                column = alt.Column('regionejecucion',title=None) 
            )
chart_pg5C
# Out:
# alt.Chart(...)

# %% [markdown]
# # 6. ¿En qué áreas se está observando un incremento en la producción científica en los últimos 3 años?

# %%
df_pg6 = df_id.groupby(['sector_equivalente','regionejecucion']).agg({'codigo':'count'}).copy().reset_index()

chart_pg6 = alt.Chart(df_pg6).mark_bar().encode(
                y = alt.Y('sector_equivalente:O',title=None),
                x = alt.X('codigo:Q', title='N° proyectos'),
                column = alt.Column('regionejecucion',title=None) 
            )
chart_pg6
# Out:
# alt.Chart(...)

# %%
# por área ocde
df_pg6B = df_id.groupby(['area_ocde','regionejecucion']).agg({'codigo':'count'}).copy().reset_index()

chart_pg6B = alt.Chart(df_pg6B).mark_bar().encode(
                y = alt.Y('area_ocde:O',title=None),
                x = alt.X('codigo:Q', title='N° proyectos'),
                column = alt.Column('regionejecucion',title=None) 
            )
chart_pg6B
# Out:
# alt.Chart(...)

# %%
# por área ocde
df_pg6C = df_id.groupby(['area_anid','regionejecucion']).agg({'codigo':'count'}).copy().reset_index()

chart_pg6C = alt.Chart(df_pg6C).mark_bar().encode(
                y = alt.Y('area_anid:O',title=None),
                x = alt.X('codigo:Q', title='N° proyectos'),
                column = alt.Column('regionejecucion',title=None) 
            )
chart_pg6C
# Out:
# alt.Chart(...)

# %% [markdown]
# # 7. ¿Observan áreas de proyección para la región? Demostrar cuantitativamente.
