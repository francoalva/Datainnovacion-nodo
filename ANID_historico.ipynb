# %%
import pandas as pd
import altair as alt

# Adjudicaciones de proyectos
URL = 'https://raw.githubusercontent.com/ANID-GITHUB/Historico-de-Proyectos-Adjudicados/master/BDH_Proyectos.csv'
df_adjudicaciones = pd.read_csv(URL, sep=';')

# %%
df_adjudicaciones.head()
# Out:
#   CODIGO_PROYECTO  N                SUBDIRECCION PROGRAMA_CONICYT INSTRUMENTO  \
# 0         1820005  1  PROYECTOS DE INVESTIGACION         FONDECYT     REGULAR
# 1         1820006  2  PROYECTOS DE INVESTIGACION         FONDECYT     REGULAR
# 2         1820009  3  PROYECTOS DE INVESTIGACION         FONDECYT     REGULAR
# 3         1820010  4  PROYECTOS DE INVESTIGACION         FONDECYT     REGULAR
# 4         1820015  5  PROYECTOS DE INVESTIGACION         FONDECYT     REGULAR
#
#                   NOMBRE_CONCURSO  AÑO_CONCURSO  AÑO_FALLO  \
# 0  CONCURSO NACIONAL REGULAR 1982          1982       1982
# 1  CONCURSO NACIONAL REGULAR 1982          1982       1982
# 2  CONCURSO NACIONAL REGULAR 1982          1982       1982
# 3  CONCURSO NACIONAL REGULAR 1982          1982       1982
# 4  CONCURSO NACIONAL REGULAR 1982          1982       1982
#
#                                      NOMBRE_PROYECTO  \
# 0  SORCION Y DESORCION DE METALES PESADOS EN SUELOS.
# 1  ESTIMACION DEL IMPACTO DEL SANEAMIENTO BASICO ...
# 2        EFECTOS NO IDEALES EN UN PLASMA CILINDRICO.
# 3  ESTUDIO SOBRE LA CONCIENCIA DE LA REALIDAD POL...
# 4  ESTUDIO DE INTERACCIONES ENTRE "BIOELECTROQUIM...
#
#                         AREA_OCDE  ...   GRUPO_DE_EVALUACION DURACION_MESES  \
# 0              CIENCIAS NATURALES  ...               QUIMICA             12
# 1  CIENCIAS MEDICAS Y DE LA SALUD  ...            MEDICINA 1             12
# 2              CIENCIAS NATURALES  ...  FISICA TEORICA Y EXP             12
# 3                     HUMANIDADES  ...              HISTORIA             12
# 4              CIENCIAS NATURALES  ...               QUIMICA             12
#
#   TIPO_BENEFICIARIO                 NOMBRE_RESPONSABLE    SEXO  \
# 0   PERSONA NATURAL    EDUARDO VICTOR SCHALSCHA BECKER  HOMBRE
# 1   PERSONA NATURAL  ANGEL CLAUDIO FLISFISCH FERNANDEZ  HOMBRE
# 2   PERSONA NATURAL             LUIS GOMBEROFF JAIKLES  HOMBRE
# 3   PERSONA NATURAL     PEDRO CRISTIAN GAZMURI RIVEROS  HOMBRE
# 4   PERSONA NATURAL        JUAN ARTURO SQUELLA SERRANO  HOMBRE
#
#                                INSTITUCION_PRINCIPAL  \
# 0                               UNIVERSIDAD DE CHILE
# 1  FACULTAD LATINOAMERICANA DE CIENCIAS SOCIALES-...
# 2                               UNIVERSIDAD DE CHILE
# 3                                         PARTICULAR
# 4                               UNIVERSIDAD DE CHILE
#
#   MACROZONA MINCIENCIA (segUn ax)   REGION_EJECUCION  \
# 0                              RM  13. METROPOLITANA
# 1                              RM  13. METROPOLITANA
# 2                              RM  13. METROPOLITANA
# 3                              RM  13. METROPOLITANA
# 4                              RM  13. METROPOLITANA
#
#   MONTO ADJUDICADO (MILES $) M$_SINFO_NOSOLICITA
# 0                        300                 NaN
# 1                        130                 NaN
# 2                        506                 NaN
# 3                        335                 NaN
# 4                        260                 NaN
#
# [5 rows x 21 columns]

# %%
df_adjudicaciones.columns
# Out:
# Index(['CODIGO_PROYECTO', 'N', 'SUBDIRECCION', 'PROGRAMA_CONICYT',
#        'INSTRUMENTO', 'NOMBRE_CONCURSO', 'AÑO_CONCURSO', 'AÑO_FALLO',
#        'NOMBRE_PROYECTO', 'AREA_OCDE', 'DISCIPLINA_DETALLE',
#        'GRUPO_DE_EVALUACION', 'DURACION_MESES', 'TIPO_BENEFICIARIO',
#        'NOMBRE_RESPONSABLE', 'SEXO', 'INSTITUCION_PRINCIPAL',
#        'MACROZONA MINCIENCIA (segUn ax)', 'REGION_EJECUCION',
#        'MONTO ADJUDICADO (MILES $)', 'M$_SINFO_NOSOLICITA'],
#       dtype='object')

# %%
df_adjudicaciones['N'].unique()
# Out:
# array([    1,     2,     3, ..., 37202, 37203, 37204])
